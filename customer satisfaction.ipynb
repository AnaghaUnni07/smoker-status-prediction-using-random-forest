# %%
import pandas as pd 
import sklearn 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()
print()
sc=StandardScaler()
path="C:/Users/anu_n/OneDrive/Desktop/PythonSandbox/PythonML_internship/internshipProject/datasets/train_dataset (2).csv"
data=pd.read_csv(path)
le_satisfaction=LabelEncoder() 
datarsatisfactioni=le_satisfaction.fit_transform(data['satisfaction'])
print(data) 
inputs=data.drop('satisfaction','columns')
outputs=data['satisfaction']
x_train,x_test,y_train,y_test=train_test_split(inputs,outputs,test_size=0.1)
x_train= sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print(y_pred)
print(y_test)
print(accuracy_score(y_test, y_pred)*100)
# Out:
#        Age  Flight Distance  Inflight wifi service  \
# 0       35              971                      3
# 1       32             1092                      0
# 2       46             2915                      0
# 3       56             2556                      4
# 4       54              468                      1
# ...    ...              ...                    ...
# 50756   41             3937                      4
# 50757   40              265                      5
# 50758   51             1750                      1
# 50759   18              296                      3
# 50760   24              581                      3
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# 0                                      4                       5
# 1                                      0                       0
# 2                                      5                       0
# 3                                      4                       4
# ...
